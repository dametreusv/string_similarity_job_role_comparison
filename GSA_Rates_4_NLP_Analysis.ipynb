# %%
import os
import numpy as np
import pandas as pd
#from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, MaxPooling1D
#from keras.models import Sequential
#from keras.preprocessing.text import Tokenizer
#from keras.preprocessing.sequence import pad_sequences
#from keras.metrics import categorical_accuracy

df = pd.read_csv('merged_rates/rates_analysis.csv').drop('Unnamed: 0', axis=1).rename(columns={'responsibility':'functional_responsibility'})
df.head()
# Out:
#                       role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0   Senior Program Manager     442.04     454.86     468.05     481.62
# 1          Program Manager     389.42     400.71     412.33     424.29
# 2          Project Manager     252.85     260.18     267.73     275.49
# 3             Task Manager     190.81     196.34     202.03     207.89
# 4  Subject Matter Expert 1     225.85     232.40     239.14     246.08
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
# 1        NaN        NaN        NaN  Bachelor's
# 2        NaN        NaN        NaN  Bachelor's
# 3        NaN        NaN        NaN  Bachelor's
# 4        NaN        NaN        NaN  Bachelor's
#
#                            functional_responsibility  ... 2021_2022_min  \
# 0  The Senior Program Manager has overall account...  ...        481.62
# 1  Program Managers plan and manage projects to c...  ...         74.81
# 2  The Project Manager manages, plans and coordin...  ...         67.63
# 3  Task Managers apply their broad management ski...  ...        207.89
# 4  The Subject Matter Expert 1 has industry exper...  ...        246.08
#
#   2022_2023_min 2023_2024_min  2024_2025_min  1819_1920_change  \
# 0           NaN           NaN            NaN          0.029002
# 1         74.81         74.81            NaN          0.028992
# 2         67.63         67.63         134.58          0.028990
# 3           NaN           NaN            NaN          0.028982
# 4           NaN           NaN            NaN          0.029002
#
#    1920_2021_change  2021_2122_change  2122_2223_change  2223_2324_change  \
# 0          0.028998          0.028993               NaN               NaN
# 1          0.028999          0.029006               NaN               NaN
# 2          0.029018          0.028984               NaN               NaN
# 3          0.028980          0.029006               NaN               NaN
# 4          0.029002          0.029021               NaN               NaN
#
#    2324_2425_change
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8005 entries, 0 to 8004
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   role                       8004 non-null   object
#  1   2018_2019                  7882 non-null   float64
#  2   2019_2020                  7977 non-null   float64
#  3   2020_2021                  8005 non-null   float64
#  4   2021_2022                  7961 non-null   float64
#  5   2022_2023                  381 non-null    float64
#  6   2023_2024                  272 non-null    float64
#  7   2024_2025                  28 non-null     float64
#  8   education                  607 non-null    object
#  9   functional_responsibility  8005 non-null   object
#  10  yoe                        607 non-null    object
#  11  company                    8004 non-null   object
#  12  socio_economic             471 non-null    object
#  13  program                    0 non-null      float64
#  14  2018_2019_mean             7895 non-null   float64
#  15  2019_2020_mean             7980 non-null   float64
#  16  2020_2021_mean             8004 non-null   float64
#  17  2021_2022_mean             7973 non-null   float64
#  18  2022_2023_mean             951 non-null    float64
#  19  2023_2024_mean             841 non-null    float64
#  20  2024_2025_mean             38 non-null     float64
#  21  2018_2019_max              7895 non-null   float64
#  22  2019_2020_max              7980 non-null   float64
#  23  2020_2021_max              8004 non-null   float64
#  24  2021_2022_max              7973 non-null   float64
#  25  2022_2023_max              951 non-null    float64
#  26  2023_2024_max              841 non-null    float64
#  27  2024_2025_max              38 non-null     float64
#  28  2018_2019_min              7895 non-null   float64
#  29  2019_2020_min              7980 non-null   float64
#  30  2020_2021_min              8004 non-null   float64
#  31  2021_2022_min              7973 non-null   float64
#  32  2022_2023_min              951 non-null    float64
#  33  2023_2024_min              841 non-null    float64
#  34  2024_2025_min              38 non-null     float64
#  35  1819_1920_change           7882 non-null   float64
#  36  1920_2021_change           7977 non-null   float64
#  37  2021_2122_change           7961 non-null   float64
#  38  2122_2223_change           381 non-null    float64
#  39  2223_2324_change           272 non-null    float64
#  40  2324_2425_change           28 non-null     float64
# dtypes: float64(35), object(6)
# memory usage: 2.5+ MB

# %%
# Get rid of one Null row for role
df = df[df.role.notnull()]

# %% [markdown]
# ## Preprocess data and remove stopwords

# %% [markdown]
# There are 'roles' located in the 'responsibility' column.  They must be removed to better match not on the roles themselves but on the responsibilities.
#
# One problem with the job responsibilities is that we noticed that several roles are cut off in the middle of the explanation, which may hinder optimized NLP analysis.
#
# Also, the job responsibilities must be preprocessed for normalization, removing special characters, numbers, multiple spaces, shorten words with ing, etc.  This will increase the odds of having matching words within responsibilities for a better role match.

# %%
import re

# Take out role in functional responsibility
without_role = []

for r,fr in zip(df.role, df['functional_responsibility']):
    without_role.append(fr.replace(str(r),''))


# Preprocess data for normalization
preprocessed = []

for row in without_role:
    phrase = re.sub('[\n]+',' ', row) # Substitute new line characters for spaces
    phrase = phrase.lower() # Lowercase all values
    phrase = re.sub('[^A-Za-z0-9]+', ' ', phrase) # remove special characters
    phrase = re.sub('ing', ' ', phrase) # remove ing
    phrase = re.sub(r'[0-9]+', ' ', phrase) # remove numbers
    phrase = re.sub(' +', ' ', phrase) # remove double spaces
    preprocessed.append(phrase)
    
    
# Assign new data to a column and strip spaces
df['responsibility'] = preprocessed
df['responsibility'] = df.responsibility.str.strip()
df.head(1)
# Out:
#                      role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0  Senior Program Manager     442.04     454.86     468.05     481.62
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
#
#                            functional_responsibility  ... 2022_2023_min  \
# 0  The Senior Program Manager has overall account...  ...           NaN
#
#   2023_2024_min 2024_2025_min  1819_1920_change  1920_2021_change  \
# 0           NaN           NaN          0.029002          0.028998
#
#    2021_2122_change  2122_2223_change  2223_2324_change  2324_2425_change  \
# 0          0.028993               NaN               NaN               NaN
#
#                                       responsibility
# 0  the has overall accountability for business so...
#
# [1 rows x 42 columns]

# %% [markdown]
# Contractions are shortened words, e.g., don’t and can’t. Expanding such words to “do not” and “can not” helps to standardize text.

# %%
# Try and think of ways to expand contractions
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# Apply contraction
contracted = []
for row in df.responsibility:
    contracted.append(decontracted(row))
    
# reassign contraction
df['responsibility'] = contracted
df.head(1)
# Out:
#                      role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0  Senior Program Manager     442.04     454.86     468.05     481.62
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
#
#                            functional_responsibility  ... 2022_2023_min  \
# 0  The Senior Program Manager has overall account...  ...           NaN
#
#   2023_2024_min 2024_2025_min  1819_1920_change  1920_2021_change  \
# 0           NaN           NaN          0.029002          0.028998
#
#    2021_2122_change  2122_2223_change  2223_2324_change  2324_2425_change  \
# 0          0.028993               NaN               NaN               NaN
#
#                                       responsibility
# 0  the has overall accountability for business so...
#
# [1 rows x 42 columns]

# %% [markdown]
# Stopwords are the most common words in any natural language. For the purpose of analyzing text data and building NLP models, these stopwords might not add much value to the meaning of the document. Generally, the most common words used in a text are “the”, “is”, “in”, “for”, “where”, “when”, “to”, “at” etc.

# %%
# Encountering an error with nltk not being defined in order to download stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# nltk.download('stopwords')

# %%
# Printed and copy stopwords instead
print(len(stopwords.words('english')),'\n', stopwords.words('english'))
# Out:
# 179
#  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Place stop words in list
my_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 
                'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 
                'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 
                "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 
                'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 
                'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 
                'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 
                'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 
                'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 
                'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 
                'through', 'during', 'before', 'after', 'above', 'below', 'to', 
                'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 
                'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 
                'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 
                'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 
                'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 
                "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 
                've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', 
                "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 
                'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', 
                "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 
                'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# Create stopword removal function
def remove_mystopwords(sentence):
    text_tokens = sentence.split(" ")
    tokens_filtered= [word for word in text_tokens if not word in my_stopwords]
    return (" ").join(tokens_filtered)

# remove stopwords
df['responsibility'] = df.responsibility.apply(remove_mystopwords)
df['responsibility'] = df.responsibility.str.strip()
df.responsibility[:10]
# Out:
# 0    overall accountability business solution progr...
# 1    plan manage projects control overall project s...
# 2    manages plans coordinates activities projects ...
# 3    apply broad management skills specialized func...
# 4    industry experience relevant subject matter in...
# 5    industry experience relevant subject matter in...
# 6    industry experience relevant subject matter in...
# 7    provides thought leadership related current fu...
# 8    provides thought leadership related current fu...
# 9    may develop run tests implement maintain opera...
# Name: responsibility, dtype: object

# %% [markdown]
# Lemmatization is the process of converting a word to its base form, e.g., “caring” to “care”. We use spaCy’s lemmatizer to obtain the lemma, or base form, of the words. Sample code:

# %%
import spacy
nlp = spacy.load('en_core_web_sm') # load spacy model, can be "en_core_web_sm"

# Lemmatization example
text = """he kept eating while we are talking"""
doc = nlp(text)
mytokens = [word.lemma_ if word.lemma_ != "-PrON-" else word.lower_ for word in doc]
print(mytokens)
# Out:
# ['-PRON-', 'keep', 'eat', 'while', '-PRON-', 'be', 'talk']

# %%
# Apply lemmatization in order to get the base form of a word
lemmatized = []

for text in df['responsibility']:
    doc = nlp(text)
    # Lemmatizing each token
    mytokens = [word.lemma_ if word.lemma_ != "-PrON-" else word.lower_ for word in doc]
    join_list = (' ').join(mytokens) # Join list of words into a sentence
    lemmatized.append(join_list) # Append to a list
    
df['responsibility'] = lemmatized
df.responsibility[:10]
# Out:
# 0    overall accountability business solution progr...
# 1    plan manage project control overall project sc...
# 2    manages plan coordinate activity project indiv...
# 3    apply broad management skill specialized funct...
# 4    industry experience relevant subject matter in...
# 5    industry experience relevant subject matter in...
# 6    industry experience relevant subject matter in...
# 7    provide think leadership relate current future...
# 8    provide think leadership relate current future...
# 9    may develop run test implement maintain operat...
# Name: responsibility, dtype: object

# %% [markdown]
# ___
#
# After initial preprocessing, I've noticed that many of the different level roles have the same job responsibility which will hurt separating role levels.  This is only from the CIOSP3 data.
#
# ## Cosine Similarity

# %%
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sparse_dot_topn import awesome_cossim_topn


# Instaniate our lookup hash table
group_lookup = {}


# Write a function for cleaning strings and returning an array of ngrams
def ngrams_analyzer(string):
    string = re.sub(r'[,-./]', r'', string)
    ngrams = zip(*[string[i:] for i in range(5)])  # N-Gram length is 5
    return [''.join(ngram) for ngram in ngrams]


def find_group(row, col):
    # If either the row or the col string have already been given
    # a group, return that group. Otherwise return none
    if row in group_lookup:
        return group_lookup[row]
    elif col in group_lookup:
        return group_lookup[col]
    else:
        return None


def add_vals_to_lookup(group, row, col):
    # Once we know the group name, set it as the value
    # for both strings in the group_lookup
    group_lookup[row] = group
    group_lookup[col] = group


def add_pair_to_lookup(row, col):
    # in this function we'll add both the row and the col to the lookup
    group = find_group(row, col)  # first, see if one has already been added
    if group is not None:
        # if we already know the group, make sure both row and col are in lookup
        add_vals_to_lookup(group, row, col)
    else:
        # if we get here, we need to add a new group.
        # The name is arbitrary, so just make it the row
        add_vals_to_lookup(row, row, col)


# Construct vectorizer for building the TF-IDF matrix
vectorizer = TfidfVectorizer(analyzer=ngrams_analyzer)

# Grab the column you'd like to group, filter out duplicate values
# and make sure the values are Unicode
vals = df['role'].unique().astype('U')

# Build the matrix!!!
tf_idf_matrix = vectorizer.fit_transform(vals)

cosine_matrix = awesome_cossim_topn(tf_idf_matrix, tf_idf_matrix.transpose(), vals.size, 0.8)

# Build a coordinate matrix
coo_matrix = cosine_matrix.tocoo()

# for each row and column in coo_matrix
# if they're not the same string add them to the group lookup
for row, col in zip(coo_matrix.row, coo_matrix.col):
    if row != col:
        add_pair_to_lookup(vals[row], vals[col])

df['Group'] = df['role'].map(group_lookup).fillna(df['role'])

# %%
df.head()
# Out:
#                       role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0   Senior Program Manager     442.04     454.86     468.05     481.62
# 1          Program Manager     389.42     400.71     412.33     424.29
# 2          Project Manager     252.85     260.18     267.73     275.49
# 3             Task Manager     190.81     196.34     202.03     207.89
# 4  Subject Matter Expert 1     225.85     232.40     239.14     246.08
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
# 1        NaN        NaN        NaN  Bachelor's
# 2        NaN        NaN        NaN  Bachelor's
# 3        NaN        NaN        NaN  Bachelor's
# 4        NaN        NaN        NaN  Bachelor's
#
#                            functional_responsibility  ... 2023_2024_min  \
# 0  The Senior Program Manager has overall account...  ...           NaN
# 1  Program Managers plan and manage projects to c...  ...         74.81
# 2  The Project Manager manages, plans and coordin...  ...         67.63
# 3  Task Managers apply their broad management ski...  ...           NaN
# 4  The Subject Matter Expert 1 has industry exper...  ...           NaN
#
#   2024_2025_min 1819_1920_change  1920_2021_change  2021_2122_change  \
# 0           NaN         0.029002          0.028998          0.028993
# 1           NaN         0.028992          0.028999          0.029006
# 2        134.58         0.028990          0.029018          0.028984
# 3           NaN         0.028982          0.028980          0.029006
# 4           NaN         0.029002          0.029002          0.029021
#
#    2122_2223_change  2223_2324_change  2324_2425_change  \
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
# 3               NaN               NaN               NaN
# 4               NaN               NaN               NaN
#
#                                       responsibility                    Group
# 0  overall accountability business solution progr...   Senior Program Manager
# 1  plan manage project control overall project sc...          Program Manager
# 2  manages plan coordinate activity project indiv...          Project Manager
# 3  apply broad management skill specialized funct...             Task Manager
# 4  industry experience relevant subject matter in...  Subject Matter Expert 1
#
# [5 rows x 43 columns]

# %%
group_len = len(df.Group.value_counts())
df.Group.value_counts()
# Out:
# Subject Matter Expert 1                   179
# Computer Systems Analyst                  168
# Database Specialist IV                    166
# Database Management Specialist            163
# Business Process Reengineering Analyst    163
#                                          ...
# Staff Scientist                             1
# Web Tech Administrator                      1
# Computer Systems Programmer                 1
# Eng Senior: Program Manager                 1
# Principal Systems Analyst                   1
# Name: Group, Length: 404, dtype: int64

# %%
role_len = len(df.role.value_counts())
df.role.value_counts()
# Out:
# Program Manager                              60
# Network Administrator                        56
# Help Desk Specialist                         56
# Web Designer                                 56
# Database Administrator                       56
#                                              ..
# Expert Technologist I                         1
# Consultant 1                                  1
# Customer Service and Support Technician 2     1
# Business Analyst                              1
# Administrative Support Specialist 2           1
# Name: role, Length: 675, dtype: int64

# %%
# Percentage difference
per_diff = (abs(role_len - group_len)) / ((role_len + group_len) / 2)
per_diff
# Out:
# 0.5023169601482854

# %%
# Percentage change
per_change = (group_len - role_len) / role_len
per_change
# Out:
# -0.4014814814814815

# %%
df[df.Group == 'Subject Matter Expert 1'].role.value_counts()
# Out:
# Subject Matter Expert Level II     54
# Subject Matter Expert Level I      54
# Subject Matter Expert Level III    54
# Subject Matter Expert III           3
# Subject Matter Expert I             3
# Subject Matter Expert II            3
# Subject Matter Expert IV            3
# Subject Matter Expert 1             1
# Subject Matter Expert 2             1
# Subject Matter Expert VI            1
# Subject Matter Expert V             1
# Subject Matter Expert 3             1
# Name: role, dtype: int64

# %%
# See if many of these roles have the same responsibility in various companies
resp_check = df[df.Group == 'Subject Matter Expert 1']
resp_check.drop_duplicates(subset='company')
# Which they do
# Out:
#                                role  2018_2019  2019_2020  2020_2021  \
# 4           Subject Matter Expert 1     225.85     232.40     239.14
# 379        Subject Matter Expert IV     242.59     242.59     242.59
# 457        Subject Matter Expert IV     320.47     327.68     335.05
# 584         Subject Matter Expert I      49.39      50.33      51.29
# 6384  Subject Matter Expert Level I     165.20     168.50     171.87
# 6385  Subject Matter Expert Level I     175.02     180.42     185.94
# 6386  Subject Matter Expert Level I     117.74     120.10     122.49
# 6388  Subject Matter Expert Level I     165.24     170.20     175.32
# 6389  Subject Matter Expert Level I     147.73     151.72     155.82
# 6390  Subject Matter Expert Level I     117.04     119.96     122.96
# 6391  Subject Matter Expert Level I     146.62     151.03     155.56
# 6392  Subject Matter Expert Level I      86.02      88.25      90.55
# 6393  Subject Matter Expert Level I     147.83     153.01     158.36
# 6394  Subject Matter Expert Level I     176.07     181.56     187.19
# 6395  Subject Matter Expert Level I     173.58     178.79     184.15
# 6396  Subject Matter Expert Level I     112.61     115.81     119.12
# 6397  Subject Matter Expert Level I     105.33     108.36     111.49
# 6398  Subject Matter Expert Level I     117.08     120.59     124.21
# 6399  Subject Matter Expert Level I     128.95     132.69     136.63
# 6400  Subject Matter Expert Level I     103.17     106.48     109.88
# 6401  Subject Matter Expert Level I     249.69     257.18     264.89
# 6402  Subject Matter Expert Level I     135.28     137.85     140.47
# 6403  Subject Matter Expert Level I     243.17     249.86     256.73
# 6404  Subject Matter Expert Level I     124.91     128.66     132.52
# 6405  Subject Matter Expert Level I     105.33     107.96     110.66
# 6406  Subject Matter Expert Level I     119.83     124.02     128.36
# 6407  Subject Matter Expert Level I     138.30     142.44     146.72
# 6408  Subject Matter Expert Level I     111.27     113.49     115.76
# 6409  Subject Matter Expert Level I     112.91     114.60     116.32
# 6410  Subject Matter Expert Level I     132.22     133.94     135.68
# 6411  Subject Matter Expert Level I      99.91     102.91     106.00
# 6412  Subject Matter Expert Level I     146.24     150.04     154.09
# 6413  Subject Matter Expert Level I     183.53     185.37     187.22
# 6414  Subject Matter Expert Level I      92.95      95.74      98.61
# 6415  Subject Matter Expert Level I     163.22     166.48     169.81
# 6416  Subject Matter Expert Level I     155.23     159.88     164.68
# 6417  Subject Matter Expert Level I      89.02      91.61      94.26
# 6418  Subject Matter Expert Level I     159.49     163.57     167.75
# 6419  Subject Matter Expert Level I     138.06     142.20     146.46
# 6420  Subject Matter Expert Level I     188.63     193.34     198.18
# 6421  Subject Matter Expert Level I     102.10     104.65     107.27
# 6422  Subject Matter Expert Level I     135.92     138.63     141.41
# 6423  Subject Matter Expert Level I     108.91     111.09     113.31
# 6424  Subject Matter Expert Level I     137.77     141.90     146.16
# 6425  Subject Matter Expert Level I     111.48     113.71     115.98
# 6426  Subject Matter Expert Level I     124.84     127.96     131.16
# 6427  Subject Matter Expert Level I     171.75     175.70     179.74
# 6428  Subject Matter Expert Level I     129.31     132.77     136.32
# 6429  Subject Matter Expert Level I     141.76     146.29     150.97
# 6430  Subject Matter Expert Level I     133.61     136.99     140.45
# 6431  Subject Matter Expert Level I     135.21     139.27     143.45
# 6432  Subject Matter Expert Level I     160.20     165.01     169.96
# 6433  Subject Matter Expert Level I     100.22     102.72     105.29
# 6434  Subject Matter Expert Level I     160.43     165.61     170.96
# 6435  Subject Matter Expert Level I      89.02      91.61      94.26
# 6436  Subject Matter Expert Level I     139.58     142.37     145.22
# 6437  Subject Matter Expert Level I     156.33     161.02     165.85
#
#       2021_2022  2022_2023  2023_2024  2024_2025          education  \
# 4        246.08        NaN        NaN        NaN         Bachelor's
# 379      242.59        NaN        NaN        NaN                PhD
# 457         NaN        NaN        NaN        NaN  Bachelor’s Degree
# 584       52.26        NaN        NaN        NaN        Associate's
# 6384     175.31        NaN        NaN        NaN                NaN
# 6385     191.69        NaN        NaN        NaN                NaN
# 6386     124.96        NaN        NaN        NaN                NaN
# 6388     180.60        NaN        NaN        NaN                NaN
# 6389     160.03        NaN        NaN        NaN                NaN
# 6390     126.04        NaN        NaN        NaN                NaN
# 6391     160.23        NaN        NaN        NaN                NaN
# 6392      92.90        NaN        NaN        NaN                NaN
# 6393     163.91        NaN        NaN        NaN                NaN
# 6394     191.96        NaN        NaN        NaN                NaN
# 6395     189.67        NaN        NaN        NaN                NaN
# 6396     122.51        NaN        NaN        NaN                NaN
# 6397     114.71        NaN        NaN        NaN                NaN
# 6398     127.93        NaN        NaN        NaN                NaN
# 6399     140.63        NaN        NaN        NaN                NaN
# 6400     113.40        NaN        NaN        NaN                NaN
# 6401     272.84        NaN        NaN        NaN                NaN
# 6402     143.13        NaN        NaN        NaN                NaN
# 6403     263.79        NaN        NaN        NaN                NaN
# 6404     136.49        NaN        NaN        NaN                NaN
# 6405     113.43        NaN        NaN        NaN                NaN
# 6406     132.85        NaN        NaN        NaN                NaN
# 6407     151.12        NaN        NaN        NaN                NaN
# 6408     118.08        NaN        NaN        NaN                NaN
# 6409     118.07        NaN        NaN        NaN                NaN
# 6410     137.44        NaN        NaN        NaN                NaN
# 6411     109.18        NaN        NaN        NaN                NaN
# 6412     158.41        NaN        NaN        NaN                NaN
# 6413     187.22        NaN        NaN        NaN                NaN
# 6414     101.57        NaN        NaN        NaN                NaN
# 6415     173.21        NaN        NaN        NaN                NaN
# 6416     169.62        NaN        NaN        NaN                NaN
# 6417      97.00        NaN        NaN        NaN                NaN
# 6418     172.12        NaN        NaN        NaN                NaN
# 6419     150.86        NaN        NaN        NaN                NaN
# 6420     203.13        NaN        NaN        NaN                NaN
# 6421     109.95        NaN        NaN        NaN                NaN
# 6422     144.50        NaN        NaN        NaN                NaN
# 6423     115.58        NaN        NaN        NaN                NaN
# 6424     150.54        NaN        NaN        NaN                NaN
# 6425     118.30        NaN        NaN        NaN                NaN
# 6426     134.44        NaN        NaN        NaN                NaN
# 6427     183.87        NaN        NaN        NaN                NaN
# 6428     139.97        NaN        NaN        NaN                NaN
# 6429     155.81        NaN        NaN        NaN                NaN
# 6430     144.05        NaN        NaN        NaN                NaN
# 6431     147.75        NaN        NaN        NaN                NaN
# 6432     175.06        NaN        NaN        NaN                NaN
# 6433     107.92        NaN        NaN        NaN                NaN
# 6434     176.49        NaN        NaN        NaN                NaN
# 6435      97.00        NaN        NaN        NaN                NaN
# 6436     148.12        NaN        NaN        NaN                NaN
# 6437     170.82        NaN        NaN        NaN                NaN
#
#                               functional_responsibility  ... 2023_2024_min  \
# 4     The Subject Matter Expert 1 has industry exper...  ...           NaN
# 379   Provides executive-level technical, managerial...  ...           NaN
# 457   Serve as subject matter expert in a functional...  ...           NaN
# 584   Use Oracle-based system in a Client/Server env...  ...           NaN
# 6384  Subject Matter Expert Level I Provide technica...  ...           NaN
# 6385  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6386  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6388  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6389  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6390  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6391  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6392  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6393  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6394  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6395  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6396  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6397  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6398  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6399  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6400  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6401  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6402  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6403  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6404  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6405  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6406  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6407  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6408  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6409  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6410  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6411  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6412  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6413  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6414  Subject Matter Expert - Level I Provide techni...  ...           NaN
# 6415  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6416  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6417  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6418  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6419  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6420  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6421  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6422  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6423  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6424  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6425  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6426  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6427  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6428  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6429  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6430  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6431  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6432  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6433  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6434  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6435  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6436  Subject Matter Expert ? Level I Provide techni...  ...           NaN
# 6437  Subject Matter Expert ? Level I Provide techni...  ...           NaN
#
#      2024_2025_min 1819_1920_change  1920_2021_change  2021_2122_change  \
# 4              NaN         0.029002          0.029002          0.029021
# 379            NaN         0.000000          0.000000          0.000000
# 457            NaN         0.022498          0.022491               NaN
# 584            NaN         0.019032          0.019074          0.018912
# 6384           NaN         0.019976          0.020000          0.020015
# 6385           NaN         0.030854          0.030595          0.030924
# 6386           NaN         0.020044          0.019900          0.020165
# 6388           NaN         0.030017          0.030082          0.030116
# 6389           NaN         0.027009          0.027023          0.027018
# 6390           NaN         0.024949          0.025008          0.025049
# 6391           NaN         0.030078          0.029994          0.030021
# 6392           NaN         0.025924          0.026062          0.025953
# 6393           NaN         0.035040          0.034965          0.035047
# 6394           NaN         0.031181          0.031009          0.025482
# 6395           NaN         0.030015          0.029979          0.029976
# 6396           NaN         0.028417          0.028581          0.028459
# 6397           NaN         0.028767          0.028885          0.028882
# 6398           NaN         0.029980          0.030019          0.029949
# 6399           NaN         0.029003          0.029693          0.029276
# 6400           NaN         0.032083          0.031931          0.032035
# 6401           NaN         0.029997          0.029979          0.030012
# 6402           NaN         0.018998          0.019006          0.018936
# 6403           NaN         0.027512          0.027495          0.027500
# 6404           NaN         0.030022          0.030002          0.029958
# 6405           NaN         0.024969          0.025009          0.025032
# 6406           NaN         0.034966          0.034994          0.034980
# 6407           NaN         0.029935          0.030048          0.029989
# 6408           NaN         0.019951          0.020002          0.020041
# 6409           NaN         0.014968          0.015009          0.015045
# 6410           NaN         0.013009          0.012991          0.012972
# 6411           NaN         0.030027          0.030026          0.030000
# 6412           NaN         0.025985          0.026993          0.028036
# 6413           NaN         0.010026          0.009980          0.000000
# 6414           NaN         0.030016          0.029977          0.030017
# 6415           NaN         0.019973          0.020002          0.020022
# 6416           NaN         0.029956          0.030023          0.029998
# 6417           NaN         0.029095          0.028927          0.029069
# 6418           NaN         0.025582          0.025555          0.026051
# 6419           NaN         0.029987          0.029958          0.030042
# 6420           NaN         0.024970          0.025034          0.024977
# 6421           NaN         0.024976          0.025036          0.024984
# 6422           NaN         0.019938          0.020053          0.021851
# 6423           NaN         0.020017          0.019984          0.020034
# 6424           NaN         0.029977          0.030021          0.029967
# 6425           NaN         0.020004          0.019963          0.020003
# 6426           NaN         0.024992          0.025008          0.025008
# 6427           NaN         0.022999          0.022994          0.022978
# 6428           NaN         0.026757          0.026738          0.026775
# 6429           NaN         0.031955          0.031991          0.032059
# 6430           NaN         0.025298          0.025257          0.025632
# 6431           NaN         0.030027          0.030014          0.029976
# 6432           NaN         0.030025          0.029998          0.030007
# 6433           NaN         0.024945          0.025019          0.024979
# 6434           NaN         0.032288          0.032305          0.032347
# 6435           NaN         0.029095          0.028927          0.029069
# 6436           NaN         0.019989          0.020018          0.019970
# 6437           NaN         0.030001          0.029996          0.029967
#
#       2122_2223_change  2223_2324_change  2324_2425_change  \
# 4                  NaN               NaN               NaN
# 379                NaN               NaN               NaN
# 457                NaN               NaN               NaN
# 584                NaN               NaN               NaN
# 6384               NaN               NaN               NaN
# 6385               NaN               NaN               NaN
# 6386               NaN               NaN               NaN
# 6388               NaN               NaN               NaN
# 6389               NaN               NaN               NaN
# 6390               NaN               NaN               NaN
# 6391               NaN               NaN               NaN
# 6392               NaN               NaN               NaN
# 6393               NaN               NaN               NaN
# 6394               NaN               NaN               NaN
# 6395               NaN               NaN               NaN
# 6396               NaN               NaN               NaN
# 6397               NaN               NaN               NaN
# 6398               NaN               NaN               NaN
# 6399               NaN               NaN               NaN
# 6400               NaN               NaN               NaN
# 6401               NaN               NaN               NaN
# 6402               NaN               NaN               NaN
# 6403               NaN               NaN               NaN
# 6404               NaN               NaN               NaN
# 6405               NaN               NaN               NaN
# 6406               NaN               NaN               NaN
# 6407               NaN               NaN               NaN
# 6408               NaN               NaN               NaN
# 6409               NaN               NaN               NaN
# 6410               NaN               NaN               NaN
# 6411               NaN               NaN               NaN
# 6412               NaN               NaN               NaN
# 6413               NaN               NaN               NaN
# 6414               NaN               NaN               NaN
# 6415               NaN               NaN               NaN
# 6416               NaN               NaN               NaN
# 6417               NaN               NaN               NaN
# 6418               NaN               NaN               NaN
# 6419               NaN               NaN               NaN
# 6420               NaN               NaN               NaN
# 6421               NaN               NaN               NaN
# 6422               NaN               NaN               NaN
# 6423               NaN               NaN               NaN
# 6424               NaN               NaN               NaN
# 6425               NaN               NaN               NaN
# 6426               NaN               NaN               NaN
# 6427               NaN               NaN               NaN
# 6428               NaN               NaN               NaN
# 6429               NaN               NaN               NaN
# 6430               NaN               NaN               NaN
# 6431               NaN               NaN               NaN
# 6432               NaN               NaN               NaN
# 6433               NaN               NaN               NaN
# 6434               NaN               NaN               NaN
# 6435               NaN               NaN               NaN
# 6436               NaN               NaN               NaN
# 6437               NaN               NaN               NaN
#
#                                          responsibility  \
# 4     industry experience relevant subject matter in...
# 379   provide executive level technical managerial a...
# 457   serve subject matter expert functional technic...
# 584   use oracle base system client server environme...
# 6384  provide technical knowledge analysis highly sp...
# 6385  subject matter expert level provide technical ...
# 6386  subject matter expert level provide technical ...
# 6388  subject matter expert level provide technical ...
# 6389  subject matter expert level provide technical ...
# 6390  subject matter expert level provide technical ...
# 6391  subject matter expert level provide technical ...
# 6392  subject matter expert level provide technical ...
# 6393  subject matter expert level provide technical ...
# 6394  subject matter expert level provide technical ...
# 6395  subject matter expert level provide technical ...
# 6396  subject matter expert level provide technical ...
# 6397  subject matter expert level provide technical ...
# 6398  subject matter expert level provide technical ...
# 6399  subject matter expert level provide technical ...
# 6400  subject matter expert level provide technical ...
# 6401  subject matter expert level provide technical ...
# 6402  subject matter expert level provide technical ...
# 6403  subject matter expert level provide technical ...
# 6404  subject matter expert level provide technical ...
# 6405  subject matter expert level provide technical ...
# 6406  subject matter expert level provide technical ...
# 6407  subject matter expert level provide technical ...
# 6408  subject matter expert level provide technical ...
# 6409  subject matter expert level provide technical ...
# 6410  subject matter expert level provide technical ...
# 6411  subject matter expert level provide technical ...
# 6412  subject matter expert level provide technical ...
# 6413  subject matter expert level provide technical ...
# 6414  subject matter expert level provide technical ...
# 6415  subject matter expert level provide technical ...
# 6416  subject matter expert level provide technical ...
# 6417  subject matter expert level provide technical ...
# 6418  subject matter expert level provide technical ...
# 6419  subject matter expert level provide technical ...
# 6420  subject matter expert level provide technical ...
# 6421  subject matter expert level provide technical ...
# 6422  subject matter expert level provide technical ...
# 6423  subject matter expert level provide technical ...
# 6424  subject matter expert level provide technical ...
# 6425  subject matter expert level provide technical ...
# 6426  subject matter expert level provide technical ...
# 6427  subject matter expert level provide technical ...
# 6428  subject matter expert level provide technical ...
# 6429  subject matter expert level provide technical ...
# 6430  subject matter expert level provide technical ...
# 6431  subject matter expert level provide technical ...
# 6432  subject matter expert level provide technical ...
# 6433  subject matter expert level provide technical ...
# 6434  subject matter expert level provide technical ...
# 6435  subject matter expert level provide technical ...
# 6436  subject matter expert level provide technical ...
# 6437  subject matter expert level provide technical ...
#
#                         Group
# 4     Subject Matter Expert 1
# 379   Subject Matter Expert 1
# 457   Subject Matter Expert 1
# 584   Subject Matter Expert 1
# 6384  Subject Matter Expert 1
# 6385  Subject Matter Expert 1
# 6386  Subject Matter Expert 1
# 6388  Subject Matter Expert 1
# 6389  Subject Matter Expert 1
# 6390  Subject Matter Expert 1
# 6391  Subject Matter Expert 1
# 6392  Subject Matter Expert 1
# 6393  Subject Matter Expert 1
# 6394  Subject Matter Expert 1
# 6395  Subject Matter Expert 1
# 6396  Subject Matter Expert 1
# 6397  Subject Matter Expert 1
# 6398  Subject Matter Expert 1
# 6399  Subject Matter Expert 1
# 6400  Subject Matter Expert 1
# 6401  Subject Matter Expert 1
# 6402  Subject Matter Expert 1
# 6403  Subject Matter Expert 1
# 6404  Subject Matter Expert 1
# 6405  Subject Matter Expert 1
# 6406  Subject Matter Expert 1
# 6407  Subject Matter Expert 1
# 6408  Subject Matter Expert 1
# 6409  Subject Matter Expert 1
# 6410  Subject Matter Expert 1
# 6411  Subject Matter Expert 1
# 6412  Subject Matter Expert 1
# 6413  Subject Matter Expert 1
# 6414  Subject Matter Expert 1
# 6415  Subject Matter Expert 1
# 6416  Subject Matter Expert 1
# 6417  Subject Matter Expert 1
# 6418  Subject Matter Expert 1
# 6419  Subject Matter Expert 1
# 6420  Subject Matter Expert 1
# 6421  Subject Matter Expert 1
# 6422  Subject Matter Expert 1
# 6423  Subject Matter Expert 1
# 6424  Subject Matter Expert 1
# 6425  Subject Matter Expert 1
# 6426  Subject Matter Expert 1
# 6427  Subject Matter Expert 1
# 6428  Subject Matter Expert 1
# 6429  Subject Matter Expert 1
# 6430  Subject Matter Expert 1
# 6431  Subject Matter Expert 1
# 6432  Subject Matter Expert 1
# 6433  Subject Matter Expert 1
# 6434  Subject Matter Expert 1
# 6435  Subject Matter Expert 1
# 6436  Subject Matter Expert 1
# 6437  Subject Matter Expert 1
#
# [57 rows x 43 columns]

# %%
# Construct vectorizer for building the TF-IDF matrix
vectorizer = TfidfVectorizer(analyzer=ngrams_analyzer)

# Grab the column you'd like to group, filter out duplicate values
# and make sure the values are Unicode
vals = df['responsibility'].unique().astype('U')

# Build the matrix!!!
tf_idf_matrix = vectorizer.fit_transform(vals)

cosine_matrix = awesome_cossim_topn(tf_idf_matrix, tf_idf_matrix.transpose(), vals.size, 0.8)

# Build a coordinate matrix
coo_matrix = cosine_matrix.tocoo()

# for each row and column in coo_matrix
# if they're not the same string add them to the group lookup
for row, col in zip(coo_matrix.row, coo_matrix.col):
    if row != col:
        add_pair_to_lookup(vals[row], vals[col])

df['Group_2'] = df['responsibility'].map(group_lookup).fillna(df['responsibility'])

# %%
resp_len = len(df.responsibility.value_counts())
df['responsibility'].value_counts()

# %%
group2_len = len(df.Group_2.value_counts())
df.Group_2.value_counts()

# %%
# Percentage difference
per_diff = (abs(resp_len - group2_len)) / ((resp_len + group2_len) / 2)
per_diff

# %%
# Percentage change
per_change = (group2_len - resp_len) / resp_len
per_change

# %%
phrase = 'organizes direct network installation site survey assess document current site network configuration user requirement design optimize network topology direct lead preparation engineer plan site installation technical design package develop installation schedule prepare site installation test report coordinate post installation operation maintenance support'

# %%
# Look into the roles more individually to see what the actual roles are
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
phrase = 'assist daily activity configuration operation system may mainframe mini client server base assist optimiz system operation resource utilization perform system capacity analysis plann provide assistance user access us business system commensurate experience education'

# %%
# Look into the roles more individually to see what the actual roles are
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
# See if many of these roles have the same responsibility in various companies
resp_check = df[df.Group_2 == phrase]
resp_check.drop_duplicates(subset='company')
# Which they do

# %%
# Adjusted cosine cut off to 0.6

# %%
phrase = 'provide configuration management plann describe provision configuration identification change control configuration status account configuration audits regulate change process approve validate change incorporate product document relate software'

# %%
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
# partial phrase
phrase = 'measurement technique'
# Note that the substring has to match a substring within the string, 2 words can't be in 2 different places
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
# Create away to put in a series of words and have it return all responsibilities with it, then all roles
# Must turn haystack into df.role and loop through each one
import re

def find_string(needle, haystack):
    re_string = '.*'.join(needle)
    rEGEX = re.compile(re_string)
    return rEGEX.findall(haystack)

# %% [markdown]
# ___
# ## Topic Modeling

# %%
from sklearn.feature_extraction.text import CountVectorizer
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import nltk
nltk.download('stopwords')
import pandas as pd
import re
import math

# %%
# Tokenize text (split words into a list)
def split_line(text):
    # split the text
    words = text.split()
    return words

df['Tokenized'] = df.responsibility.apply(split_line)
df.head()

# %%
# Create bag of words and find most frequent words
def get_most_freq_words(str, n=None):
    vect = CountVectorizer().fit(str)
    bag_of_words = vect.transform(str)
    sum_words = bag_of_words.sum(axis=0) 
    freq = [(word, sum_words[0, idx]) for word, idx in vect.vocabulary_.items()]
    freq =sorted(freq, key = lambda x: x[1], reverse=True)
    return freq[:n]
  
get_most_freq_words([ word for responsibility in df.Tokenized for word in responsibility],10)

# %%
# Find number of topics


# build a dictionary where for each tweet, each word has its own id.
# We have 6882 tweets and 10893 words in the dictionary.
responsibility_dictionary = Dictionary(df.Tokenized)

# build the corpus i.e. vectors with the number of occurence of each word per tweet
responsibility_corpus = [responsibility_dictionary.doc2bow(responsibility) for responsibility in df.Tokenized]

# compute coherence
responsibility_coherence = []
for nb_topics in range(1,36):
    lda = LdaModel(responsibility_corpus, num_topics = nb_topics, id2word = responsibility_dictionary, passes=10)
    cohm = CoherenceModel(model=lda, corpus=responsibility_corpus, dictionary=responsibility_dictionary, coherence='u_mass')
    coh = cohm.get_coherence()
    responsibility_coherence.append(coh)

# %%
# visualize coherence (number of topics is where the plateau begins)
plt.figure(figsize=(10,5))
plt.plot(range(1,36),responsibility_coherence)
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.show()

# %%
k = 15
responsibility_lda = LdaModel(responsibility_corpus, num_topics = k, id2word = responsibility_dictionary, passes=10)

def plot_top_words(lda=responsibility_lda, nb_topics=k, nb_words=10):
    top_words = [[word for word,_ in lda.show_topic(topic_id, topn=50)] for topic_id in range(lda.num_topics)]
    top_betas = [[beta for _,beta in lda.show_topic(topic_id, topn=50)] for topic_id in range(lda.num_topics)]

    gs  = gridspec.GridSpec(round(math.sqrt(k))+1,round(math.sqrt(k))+1)
    gs.update(wspace=0.5, hspace=0.5)
    plt.figure(figsize=(20,15))
    for i in range(nb_topics):
        ax = plt.subplot(gs[i])
        plt.barh(range(nb_words), top_betas[i][:nb_words], align='center',color='blue', ecolor='black')
        ax.invert_yaxis()
        ax.set_yticks(range(nb_words))
        ax.set_yticklabels(top_words[i][:nb_words])
        plt.title("Topic "+str(i))
        
  
plot_top_words()

# %%
# partial phrase
phrase = 'implement database security'
# Note that the substring has to match a substring within the string, 2 words can't be in 2 different places
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
# partial phrase
phrase = 'infrastructure'
# Note that the substring has to match a substring within the string, 2 words can't be in 2 different places
df[df.Group_2.str.contains(phrase)].role.value_counts()

# %%
# This is not good as well because we poses an 'OR' statement but just drops duplicates
phrase = 'implement database security'
role_search = split_line(phrase)

df2 = df[df.responsibility.str.contains('|'.join(role_search))].drop_duplicates('responsibility')
df2

# %%
phrase = 'implement test run'
role_search = split_line(phrase)

for tokenized in df.Tokenized:
    if all(item in tokenized for item in role_search):
        print(tokenized)

# %%
phrase = 'implement test run'
role_search = split_line(phrase)

for responsibility in df.responsibility:
    if all(item in responsibility for item in role_search):
        print(responsibility)

# %%
phrase = 'implement test run'
role_search = split_line(phrase)

roles = []
for responsibility in df.responsibility:
    if all(item in responsibility for item in role_search):
        roles.append(responsibility)
        
df2 = df[df.responsibility.str.contains('|'.join(roles))].drop_duplicates('responsibility')
df2

# %%
phrase = 'analyze system'
role_search = split_line(phrase)

roles = []
for responsibility in df.responsibility:
    if all(item in responsibility for item in role_search):
        roles.append(responsibility)
        
df2 = df[df.responsibility.str.contains('|'.join(roles))].drop_duplicates('responsibility')
df2

# %%
df2.role.value_counts()

# %%
df2.company.value_counts()

# %%
df2.responsibility.nunique()

# %%
plot_top_words()

# %%
def find_role(phrase):
    global df2
    role_search = split_line(phrase)
    
    roles = []
    for responsibility in df.responsibility:
        if all(item in responsibility for item in role_search):
            roles.append(responsibility)
        
    df2 = df[df.responsibility.str.contains('|'.join(roles))].drop_duplicates('responsibility')
    df2 = df2.drop(['Group', 'Group_2', 'Tokenized'], axis=1)
    
    import sweetviz as sv

    my_report = sv.analyze(df2)
    # my_report.show_html() # Default arguments will generate to "SWEETVIZ_rEPOrT.html"
    return my_report.show_notebook()

# %%
df[df.company == 'Gunnison Consulting']

# %%
find_role('implement database security')

# %%
df2
