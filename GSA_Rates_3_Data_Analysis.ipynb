# %%
# Import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling as profile_report
from pathlib import Path
# %matplotlib inline

# Read in rate data
rates = pd.read_csv('merged_rates/gsa.csv')
rates.rename(columns={'Role':'role', 'Education':'education', 'Functional Responsibility':'responsibility',
             'Years of Experience':'yoe', 'Company':'company', 'Program Name':'program'}, inplace=True)
rates.drop('Unnamed: 0', axis=1, inplace=True)

# %%
rates.head(3)
# Out:
#                      role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0  Senior Program Manager     442.04     454.86     468.05     481.62
# 1         Program Manager     389.42     400.71     412.33     424.29
# 2         Project Manager     252.85     260.18     267.73     275.49
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
# 1        NaN        NaN        NaN  Bachelor's
# 2        NaN        NaN        NaN  Bachelor's
#
#                                       responsibility  yoe  \
# 0  The Senior Program Manager has overall account...   15
# 1  Program Managers plan and manage projects to c...   12
# 2  The Project Manager manages, plans and coordin...   10
#
#                       company             socio_economic
# 0  Accenture Federal Services  Other than small business
# 1  Accenture Federal Services  Other than small business
# 2  Accenture Federal Services  Other than small business

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   role            628 non-null    object
#  1   2018_2019       504 non-null    float64
#  2   2019_2020       600 non-null    float64
#  3   2020_2021       628 non-null    float64
#  4   2021_2022       584 non-null    float64
#  5   2022_2023       382 non-null    float64
#  6   2023_2024       273 non-null    float64
#  7   2024_2025       28 non-null     float64
#  8   education       628 non-null    object
#  9   responsibility  628 non-null    object
#  10  yoe             628 non-null    int64
#  11  company         628 non-null    object
#  12  socio_economic  492 non-null    object
# dtypes: float64(7), int64(1), object(5)
# memory usage: 63.9+ KB

# %%
rates.describe()
# Out:
#          2018_2019   2019_2020   2020_2021   2021_2022   2022_2023  \
# count   504.000000  600.000000  628.000000  584.000000  382.000000
# mean    129.732242  134.111000  135.703089  138.103767  137.320314
# std      71.443933   61.182919   62.942137   64.828446   64.535651
# min      25.570000    9.820000    9.820000    9.820000    9.820000
# 25%      87.420000   87.655000   88.432500   89.470000   91.402500
# 50%     118.205000  122.390000  123.340000  125.770000  124.750000
# 75%     161.500000  168.842500  171.825000  173.565000  166.877500
# max    1113.970000  454.860000  468.050000  481.620000  349.250000
#
#         2023_2024   2024_2025         yoe
# count  273.000000   28.000000  628.000000
# mean   131.854908  115.535714    5.711783
# std     67.591964   65.380389    4.797134
# min      9.820000   38.450000    0.000000
# 25%     86.650000   80.352500    2.000000
# 50%    111.650000  102.280000    5.000000
# 75%    165.960000  134.580000    8.000000
# max    343.730000  349.920000   20.000000

# %%
# Grab mean, min and max data and merge into rates dataframe
mean_ = rates.groupby('role').mean()
max_ = rates.groupby('role').max(numeric_only=True)
min_ = rates.groupby('role').min(numeric_only=True)

# Rename mean, min and columns
mean_.rename(columns={'2018_2019':'2018_2019_mean', '2019_2020':'2019_2020_mean', 
                      '2020_2021':'2020_2021_mean', '2021_2022':'2021_2022_mean', 
                      '2022_2023':'2022_2023_mean', '2023_2024':'2023_2024_mean', 
                      '2024_2025':'2024_2025_mean'}, inplace=True)

min_.rename(columns={'2018_2019':'2018_2019_min', '2019_2020':'2019_2020_min', 
                      '2020_2021':'2020_2021_min', '2021_2022':'2021_2022_min', 
                      '2022_2023':'2022_2023_min', '2023_2024':'2023_2024_min', 
                      '2024_2025':'2024_2025_min'}, inplace=True)

max_.rename(columns={'2018_2019':'2018_2019_max', '2019_2020':'2019_2020_max', 
                      '2020_2021':'2020_2021_max', '2021_2022':'2021_2022_max', 
                      '2022_2023':'2022_2023_max', '2023_2024':'2023_2024_max', 
                      '2024_2025':'2024_2025_max'}, inplace=True)

# Merge aggregated data to rates
first = pd.merge(rates, mean_.reset_index(), how='left', on='role')
second = pd.merge(first, max_.reset_index(), how='left', on='role')
third = pd.merge(second, min_.reset_index(), how='left', on='role')
rates = third.copy()

# Find year to year change in rates
rates['1819_1920_change'] = (rates['2019_2020'] - rates['2018_2019']) / rates['2018_2019']
rates['1920_2021_change'] = (rates['2020_2021'] - rates['2019_2020']) / rates['2019_2020']
rates['2021_2122_change'] = (rates['2021_2022'] - rates['2020_2021']) / rates['2020_2021']
rates['2122_2223_change'] = (rates['2022_2023'] - rates['2021_2022']) / rates['2021_2022']
rates['2223_2324_change'] = (rates['2023_2024'] - rates['2022_2023']) / rates['2022_2023']
rates['2324_2425_change'] = (rates['2024_2025'] - rates['2023_2024']) / rates['2023_2024']

rates.head(3)
# Out:
#                      role  2018_2019  2019_2020  2020_2021  2021_2022  \
# 0  Senior Program Manager     442.04     454.86     468.05     481.62
# 1         Program Manager     389.42     400.71     412.33     424.29
# 2         Project Manager     252.85     260.18     267.73     275.49
#
#    2022_2023  2023_2024  2024_2025   education  \
# 0        NaN        NaN        NaN  Bachelor's
# 1        NaN        NaN        NaN  Bachelor's
# 2        NaN        NaN        NaN  Bachelor's
#
#                                       responsibility  ...  2022_2023_min  \
# 0  The Senior Program Manager has overall account...  ...            NaN
# 1  Program Managers plan and manage projects to c...  ...          74.81
# 2  The Project Manager manages, plans and coordin...  ...          67.63
#
#   2023_2024_min 2024_2025_min  yoe_y  1819_1920_change  1920_2021_change  \
# 0           NaN           NaN     15          0.029002          0.028998
# 1         74.81           NaN      4          0.028992          0.028999
# 2         67.63        134.58      4          0.028990          0.029018
#
#    2021_2122_change  2122_2223_change  2223_2324_change  2324_2425_change
# 0          0.028993               NaN               NaN               NaN
# 1          0.029006               NaN               NaN               NaN
# 2          0.028984               NaN               NaN               NaN
#
# [3 rows x 43 columns]

# %%
rates.columns
# Out:
# Index(['role', '2018_2019', '2019_2020', '2020_2021', '2021_2022', '2022_2023',
#        '2023_2024', '2024_2025', 'education', 'responsibility', 'yoe_x',
#        'company', 'socio_economic', '2018_2019_mean', '2019_2020_mean',
#        '2020_2021_mean', '2021_2022_mean', '2022_2023_mean', '2023_2024_mean',
#        '2024_2025_mean', 'yoe_y', '2018_2019_max', '2019_2020_max',
#        '2020_2021_max', '2021_2022_max', '2022_2023_max', '2023_2024_max',
#        '2024_2025_max', 'yoe_x', '2018_2019_min', '2019_2020_min',
#        '2020_2021_min', '2021_2022_min', '2022_2023_min', '2023_2024_min',
#        '2024_2025_min', 'yoe_y', '1819_1920_change', '1920_2021_change',
#        '2021_2122_change', '2122_2223_change', '2223_2324_change',
#        '2324_2425_change'],
#       dtype='object')

# %%
rates
# Out:
#                                       role  2018_2019  2019_2020  2020_2021  \
# 0                   Senior Program Manager     442.04     454.86     468.05
# 1                          Program Manager     389.42     400.71     412.33
# 2                          Project Manager     252.85     260.18     267.73
# 3                             Task Manager     190.81     196.34     202.03
# 4                  Subject Matter Expert 1     225.85     232.40     239.14
# ..                                     ...        ...        ...        ...
# 623          Junior Database Administrator     113.46     115.61     117.81
# 624                        Network Analyst      92.42      94.18      95.97
# 625  Telecommunications Network Specialist     101.97     103.91     105.88
# 626          Data Communication Specialist     105.26     107.26     109.30
# 627                Business Analyst/Writer     131.09     133.59     136.12
#
#      2021_2022  2022_2023  2023_2024  2024_2025   education  \
# 0       481.62        NaN        NaN        NaN  Bachelor's
# 1       424.29        NaN        NaN        NaN  Bachelor's
# 2       275.49        NaN        NaN        NaN  Bachelor's
# 3       207.89        NaN        NaN        NaN  Bachelor's
# 4       246.08        NaN        NaN        NaN  Bachelor's
# ..         ...        ...        ...        ...         ...
# 623     120.05        NaN        NaN        NaN  Bachelor's
# 624      97.79        NaN        NaN        NaN  Bachelor's
# 625     107.89        NaN        NaN        NaN  Bachelor's
# 626     111.38        NaN        NaN        NaN  Bachelor's
# 627     138.71        NaN        NaN        NaN          HS
#
#                                         responsibility  ...  2022_2023_min  \
# 0    The Senior Program Manager has overall account...  ...            NaN
# 1    Program Managers plan and manage projects to c...  ...          74.81
# 2    The Project Manager manages, plans and coordin...  ...          67.63
# 3    Task Managers apply their broad management ski...  ...            NaN
# 4    The Subject Matter Expert 1 has industry exper...  ...            NaN
# ..                                                 ...  ...            ...
# 623  Independently or as part of the team provides ...  ...            NaN
# 624  Responsible for site survey, acquisition, inst...  ...            NaN
# 625  Analyzes network characteristics (e.g., traffi...  ...            NaN
# 626  Analyzes data communication needs through surv...  ...            NaN
# 627  Assists in collecting and organizing informati...  ...            NaN
#
#     2023_2024_min 2024_2025_min  yoe_y  1819_1920_change  1920_2021_change  \
# 0             NaN           NaN     15          0.029002          0.028998
# 1           74.81           NaN      4          0.028992          0.028999
# 2           67.63        134.58      4          0.028990          0.029018
# 3             NaN           NaN      4          0.028982          0.028980
# 4             NaN           NaN     10          0.029002          0.029002
# ..            ...           ...    ...               ...               ...
# 623           NaN           NaN      2          0.018949          0.019029
# 624           NaN           NaN      2          0.019043          0.019006
# 625           NaN           NaN      2          0.019025          0.018959
# 626           NaN           NaN      4          0.019001          0.019019
# 627           NaN           NaN      1          0.019071          0.018939
#
#      2021_2122_change  2122_2223_change  2223_2324_change  2324_2425_change
# 0            0.028993               NaN               NaN               NaN
# 1            0.029006               NaN               NaN               NaN
# 2            0.028984               NaN               NaN               NaN
# 3            0.029006               NaN               NaN               NaN
# 4            0.029021               NaN               NaN               NaN
# ..                ...               ...               ...               ...
# 623          0.019014               NaN               NaN               NaN
# 624          0.018964               NaN               NaN               NaN
# 625          0.018984               NaN               NaN               NaN
# 626          0.019030               NaN               NaN               NaN
# 627          0.019027               NaN               NaN               NaN
#
# [628 rows x 43 columns]

# %%
# Grab mean, min and max data and merge into rates dataframe
agg = rates.groupby('role').agg(['mean', 'min', 'max'])
agg.head()
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-7-63743fa85c45> in <module>
#       1 # Grab mean, min and max data and merge into rates dataframe
# ----> 2 agg = rates.groupby('role').agg(['mean', 'min', 'max'])
#       3 agg.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     568         # we require a list, but not an 'str'
#     569         arg = cast(List[AggFuncTypeBase], arg)
# --> 570         return agg_list_like(obj, arg, _axis=_axis), None
#     571     else:
#     572         result = None
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/aggregation.py in agg_list_like(obj, arg, _axis)
#     657
#     658     try:
# --> 659         return concat(results, keys=keys, axis=1, sort=False)
#     660     except TypeError as err:
#     661
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     293         verify_integrity=verify_integrity,
#     294         copy=copy,
# --> 295         sort=sort,
#     296     )
#     297
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     465         self.copy = copy
#     466
# --> 467         self.new_axes = self._get_new_axes()
#     468
#     469     def get_result(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     537         return [
#     538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
# --> 539             for i in range(ndim)
#     540         ]
#     541
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     537         return [
#     538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
# --> 539             for i in range(ndim)
#     540         ]
#     541
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     593         else:
#     594             concat_axis = _make_concat_multiindex(
# --> 595                 indexes, self.keys, self.levels, self.names
#     596             )
#     597
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _make_concat_multiindex(indexes, keys, levels, names)
#     694     for hlevel, level in zip(zipped, levels):
#     695         hlevel = ensure_index(hlevel)
# --> 696         mapped = level.get_indexer(hlevel)
#     697
#     698         mask = mapped == -1
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3170         if not self.is_unique:
#    3171             raise InvalidIndexError(
# -> 3172                 "Reindexing only valid with uniquely valued Index objects"
#    3173             )
#    3174
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
rates.to_csv('merged_rates/gsa_analysis.csv')

# %%
import sweetviz as sv

my_report = sv.analyze(rates)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# my_report.show_notebook()

# %%
# Create html window to open report
profile = rates.profile_report()
profile.to_file(Path('./rates_eda.html'))
